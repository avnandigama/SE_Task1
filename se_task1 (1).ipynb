# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate temperature based on humidity
def calculate_temperature(humidity):
    # Coefficients of the quadratic equation for temperature based on humidity
    a = 0.002
    b = 0.1
    c = 20.0

    # Quadratic equation: T(h) = ah^2 + bh + c
    temperature = a * humidity**2 + b * humidity + c
    return temperature

# Generate humidity values from 0 to 100 with a step of 1
humidities = np.arange(0, 101, 1)

# Calculate temperatures for each humidity value
temperatures = [calculate_temperature(humidity) for humidity in humidities]

# Plotting for humidity
plt.plot(humidities, temperatures, label='Temperature', color='red')
plt.title('Temperature vs. Humidity')
plt.xlabel('Humidity')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# Function to calculate temperature based on pressure
def calculate_temperature_from_pressure(pressure):
    # Example linear relationship: T(p) = 0.02p + 10.0
    slope = 0.02
    intercept = 10.0

    temperature = slope * pressure + intercept
    return temperature

# Generate pressure values from 900 to 1100 with a step of 1
pressures = np.arange(900, 1101, 1)

# Calculate temperatures for each pressure value
temperatures = [calculate_temperature_from_pressure(p) for p in pressures]

# Plotting for pressure
plt.plot(pressures, temperatures, label='Temperature', color='red')
plt.title('Temperature vs. Pressure')
plt.xlabel('Pressure')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %%
# Function to calculate temperature based on humidity
def calculate_temperature(humidity):
    # Coefficients of the quadratic equation for temperature based on humidity
    a = 0.002
    b = 0.1
    c = 20.0

    # Quadratic equation: T(h) = ah^2 + bh + c
    temperature = a * humidity**2 + b * humidity + c
    return temperature

# Function to calculate temperature based on pressure
def calculate_temperature_from_pressure(pressure):
    # Example linear relationship: T(p) = 0.02p + 10.0
    slope = 0.02
    intercept = 10.0

    # Linear equation: T(p) = slope * pressure + intercept
    temperature = slope * pressure + intercept
    return temperature

# Example usage:
pressure = 1000
# Calculate temperature for the given pressure
temperature1 = calculate_temperature_from_pressure(pressure)
print('Temperature for Pressure', pressure, 'is', temperature1)

humidity = 40
# Calculate temperature for the given humidity
temperature2 = calculate_temperature(humidity)
print('Temperature for Humidity', humidity, 'is', temperature2)
# Out:
# Temperature for Pressure 1000 is 30.0
# Temperature for Humidity 40 is 27.2

# %%
# Function to calculate temperature based on humidity
def calculate_temperature(humidity):
    # Coefficients of the quadratic equation for temperature based on humidity
    a = 0.002
    b = 0.1
    c = 20.0

    # Quadratic equation: T(h) = ah^2 + bh + c
    temperature = a * humidity**2 + b * humidity + c
    return temperature

# Function to calculate temperature based on pressure
def calculate_temperature_from_pressure(pressure):
    # Example linear relationship: T(p) = 0.02p + 10.0
    slope = 0.02
    intercept = 10.0

    # Linear equation: T(p) = slope * pressure + intercept
    temperature = slope * pressure + intercept
    return temperature

# User input for pressure
pressure = float(input('Enter pressure in hPa: '))
# Calculate temperature for the input pressure
temperature1 = calculate_temperature_from_pressure(pressure)
print('Temperature for Pressure', pressure, 'is', temperature1)

# User input for humidity
humidity = float(input('Enter humidity percentage: '))
# Calculate temperature for the input humidity
temperature2 = calculate_temperature(humidity)
print('Temperature for Humidity', humidity, 'is', temperature2)
# Out:
# Enter pressure in hPa: 1000
# Temperature for Pressure 1000.0 is 30.0
# Enter humidity percentage: 40
# Temperature for Humidity 40.0 is 27.2
